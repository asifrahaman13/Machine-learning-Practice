# %%
import matplotlib.pyplot as plt  
import numpy as np  
from sklearn.preprocessing import MinMaxScaler
import pandas as pd  
data=pd.read_csv("datas/data.csv")
df=pd.DataFrame(data)
scalar=MinMaxScaler(feature_range=(0,10))
rescaledx=scalar.fit_transform([df["INDUS"]])
np.set_printoptions(precision=3)
print(rescaledx)

# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import Binarizer
datas=pd.read_csv('datas/data.csv')
df=pd.DataFrame(datas)
binizer=Binarizer(threshold=6)
binizerx=binizer.fit_transform([df['RM']])
print(binizerx)

# %%
import numpy as np    
import pandas as pd   
from sklearn.preprocessing import StandardScaler
datas=pd.read_csv('datas/data.csv')
df=pd.DataFrame(datas)
scalar=StandardScaler()
scalarx=scalar.fit_transform([df['MEDV']])
print(scalarx)

# %%
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
data=pd.read_csv("datas/data.csv")
df=pd.DataFrame(data)
label=LabelEncoder()
l=[]
i=0
for element in df["AGE"]:
    l.append(label.fit_transform([df["TAX"][i]]))
    i=i+1
print(l)
