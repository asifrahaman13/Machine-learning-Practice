# %% [markdown]
# Since there is dimentionality reduction of the data actually it only is used for the faster and higher performance of the training.On the other hand sometimes it will also reduce some of the noise in the training and hence will also achieve better score in the training.But such cases are actually rare.
#
# This is also useful to reduce the dimension so that it can be easily implemented in the graph plot so that we can present our model visualisation to the people who are not data scientists and will use our result of the model.

# %%
#sklearn implementation
from sklearn.decomposition import PCA  
import numpy as np
from sklearn.datasets import load_iris
iris=load_iris()
x=iris["data"][:,(2,3)]
y=(iris["target"]==2).astype(float)
# pca = PCA()
# cumsum = np.cumsum(pca.explained_variance_ratio_)
# d = np.argmax(cumsum >= 0.95) + 1
pca=PCA(n_components=0.95)
x2D=pca.fit_transform(x)
#Reducing the dimension of the data into 2 instead of the 4 dimesnsions present earlier.
print(pca.explained_variance_ratio_)
#The explained variance ratio is the function which returns which dimension has exactly how much importance in the datasets.
# Out:
# [0.99025066]
