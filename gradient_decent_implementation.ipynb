# %%
import numpy as np 
x=2*np.random.rand(100,1)
y = 4 + 3 * x + np.random.randn(100, 1)
x_b=np.c_[np.ones((100,1)),x]
theta_best=np.linalg.inv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)
print(theta_best)


x_new = np.array([[0], [2]])
x_new_b = np.c_[np.ones((2, 1)), x_new] 
y_predict = x_new_b.dot(theta_best)
y_predict


import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x_new,y_predict,color="red")


learning_rate=0.1
n_iterations=1000
m=100
theta=np.random.rand(2,1)
for iterations in range(n_iterations):
    gradient=2/m*x_b.T.dot(x_b.dot(theta)-y)
    theta=theta-learning_rate*gradient
print(f"The value of theta is: {theta}")
#To find the values of theta using the gradient decent algorithms.
# Out:
# [[3.93602993]
#  [3.09681487]]
# The value of theta is: [[3.93602993]
#  [3.09681487]]

# %%
import numpy as np 
x=2*np.random.rand(100,1)
y = 4 + 3 * x + np.random.randn(100, 1)
x_b=np.c_[np.ones((100,1)),x]


x_new = np.array([[0], [2]])
x_new_b = np.c_[np.ones((2, 1)), x_new] 
y_predict = x_new_b.dot(theta_best)


learning_rate=0.1
n_epoch=50
t0,t1=5,50


def learning_schedule(t):
    return t0/(t+t1)


theta=np.random.rand(2,1)


for epoch in range(n_epoch):
    for i in range(m):
        random_index=np.random.randint(m)
        xi=x_b[random_index:random_index+1]
        yi=y[random_index:random_index+1]
        gradient=2*xi.T.dot(xi.dot(theta)-yi)
        learning_rate= learning_schedule(epoch * m + i)
        theta=theta-learning_rate*gradient

        
print(f"The value of theta is as follows: {theta}")
# Out:
# The value of theta is as follows: [[4.19605247]
#  [2.71686618]]

# %% [markdown]
# Linear regression using the SGD regression scikit learn model.

# %%
from sklearn.linear_model import SGDRegressor
import numpy as np 
x=2*np.random.rand(100,1)
y = 4 + 3 * x + np.random.randn(100, 1)
sgd_reg = SGDRegressor(max_iter=1000, tol=1e-3, penalty=None, eta0=0.1)
sgd_reg.fit(x, y.ravel())
print(sgd_reg.intercept_, sgd_reg.coef_)
# Out:
# [3.89016385] [3.18943992]
